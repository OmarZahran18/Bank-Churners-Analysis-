# %% [markdown]
# ### Import Liberies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Overview Data

# %%
bank_churners = pd.read_csv(r"D:\Power Bi @ITI\Python Visualization\Project\BankChurners.csv")
bank_churners.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bank_churners['Card_Category'].value_counts()
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64

# %%
bank_churners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
bank_churners.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
bank_churners.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# ### Data Manipulation

# %%
#Drop Some Columns 

bank_churners = bank_churners.drop([
    "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1",
    "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"
], axis=1)

# %%
bank_churners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
#Rename Some Columns
bank_churners.rename(columns={
    'CLIENTNUM': 'Client_Number',
    'Dependent_count': 'Dependents',
    'Months_Inactive_12_mon': 'Inactive_Months',
    'Contacts_Count_12_mon': 'Contacts_Counts'
}, inplace=True)

# %%
bank_churners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client_Number             10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependents                10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Inactive_Months           10127 non-null  int64
#  12  Contacts_Counts           10127 non-null  int64
# ...

# %% [markdown]
# ###                    EDA

# %%
bank_churners['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
bank_churners['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
bank_churners['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %% [markdown]
# ##### Distribution of Categorical Columns

# %%
# Distribution of Customers by Gender
genders = bank_churners['Gender'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    genders.values, 
    labels=genders.index, 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=['orange', 'darkblue'])

plt.title('Distribution of Customers by Gender')
plt.show()

# %% [markdown]
# Females make up the majority of customers:
# Females: 52.9% & Males: 47.1%
#
# - The gender gap is small (about 5.8%), indicating a fairly even distribution.

# %%
#Number of Customers by Education Level
edu_counts = bank_churners['Education_Level'].value_counts()

plt.figure(figsize=(8,6))
bars = plt.bar(edu_counts.index, edu_counts.values, color='royalblue')

for i, val in enumerate(edu_counts.values):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=10)

plt.title('Number of Customers by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Most customers are highly educated: The largest group of customers are graduates, followed by those with a high school education.
#
# Customer numbers decrease with higher education: Generally, as the education level increases (beyond a graduate degree), the number of customers declines. The smallest group of customers holds a doctorate.

# %%
#Number of Customers by Income_Category
income_counts = bank_churners['Income_Category'].value_counts()

plt.figure(figsize=(8,6))
bars = plt.bar(income_counts.index, income_counts.values, color='seagreen')

for i, val in enumerate(income_counts.values):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=10)

plt.title('Number of Customers by Income Category')
plt.xlabel('Income Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  The majority of customers fall into the lowest income bracket of less than $40K, and the number of customers decreases significantly as income rises.
#  This highlights income as a primary factor defining the main customer base.

# %%
#Number of Customers by martial status
marital_counts = bank_churners['Marital_Status'].value_counts()

plt.figure(figsize=(7,6))
bars = plt.bar(marital_counts.index, marital_counts.values, color='darkorange')

for i, val in enumerate(marital_counts.values):
    plt.text(i, val + 50, str(val), ha='center', va='bottom', fontsize=10)

plt.title('Number of Customers by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The customer base is overwhelmingly made up of married and single individuals. These two groups account for the vast majority of customers, while the number of divorced customers and those with an unknown marital status is very low.

# %%
    #Number of Customers by Card Category

card_category = bank_churners['Card_Category'].value_counts()

colors = plt.cm.summer(np.linspace(0, 1, len(card_category)))
bars = plt.bar(card_category.index , card_category.values , color = colors)

plt.title('#Number of Customers by Card Category')
plt.xlabel("Card Category")
plt.ylabel("Number Of Customers")

for i , value in enumerate(card_category.values):
    plt.text(i,value + 50 , str(value) , ha = 'center')
    
plt.show()

# %% [markdown]
# The customer base is heavily dominated by Blue cardholders, who make up the vast majority of users. All other card types—Silver, Gold, and Platinum—are used by a very small fraction of customers.

# %%
#Attrition By Card Category 
card_attr = pd.crosstab(bank_churners['Card_Category'], 
                        bank_churners['Attrition_Flag'], 
                        normalize='index') * 100

card_attr = card_attr[['Existing Customer', 'Attrited Customer']]

ax = card_attr.plot(kind='bar', stacked=True, 
                    color=['darkgreen', 'red'], 
                    figsize=(8,6))

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', label_type='center', fontsize=9, color='white')

plt.title('Attrition Distribution by Card Category (%)')
plt.ylabel('Percentage')
plt.xlabel('Card Category')
plt.ylim(0, 100)
plt.legend(title='Attrition Flag')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - Platinum cardholders have the highest attrition rate, meaning many premium customers are leaving. Blue cardholders are the most stable and make up the majority of the base.

# %% [markdown]
# #### Distribution of Numeric Columns

# %%
numeric_cols = ['Customer_Age', 'Credit_Limit', 'Total_Trans_Amt', 'Total_Trans_Ct']

fig, axes = plt.subplots(2, 2, figsize=(10,10))
axes = axes.flatten()
for i, col in enumerate(numeric_cols):
    axes[i].hist(bank_churners[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Number of Customers')
plt.show()

# %% [markdown]
#     - Age: Most customers are between 40 and 50 years old.
#     - Credit Limit: A large majority of customers have a low credit limit, typically less than $5,000.
#     - Total Transaction Amount: The total transaction amount for most customers is also low, generally under $5,000.
#     - Total Transaction Count: The number of transactions per customer is highest between 70 and 90, with fewer customers making a very high or very low number of transactions.

# %%
#Customer Attrition Distribution'
attrition = bank_churners['Attrition_Flag'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    attrition.values, 
    labels=attrition.index, 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=['darkgreen', 'red']
)

plt.title('Customer Attrition Distribution')
plt.show()

# %% [markdown]
# - The vast majority of the customer base, 83.9%, are existing customers. This means that only a small portion, 16.1%, of customers have left the service.

# %%
#Attrition by Gender
import matplotlib.pyplot as plt

gender_attr = pd.crosstab(bank_churners['Gender'], bank_churners['Attrition_Flag'])

gender_attr = gender_attr[['Existing Customer', 'Attrited Customer']]

ax = gender_attr.plot(kind='bar', width=0.7, figsize=(7,6), color=['darkgreen', 'red'])

for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=9)

plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Attrition Flag')
plt.show()

# %% [markdown]
# - Female customers have a slightly higher number of churned accounts than male customers, but gender does not appear to be a major factor in customer attrition since both genders have a similar proportion of existing and attrited customers.

# %%
#Correlation between Numeric Columns
numeric_cols1 = ['Customer_Age', 'Credit_Limit', 'Total_Trans_Amt', 'Total_Trans_Ct' , 'Avg_Open_To_Buy' , 'Inactive_Months']

plt.figure(figsize=(8,6))
sns.heatmap(bank_churners[numeric_cols1].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation between Numeric Columns')
plt.show()

# %% [markdown]
# - The chart shows that Total Transaction Amount and Total Transaction Count are strongly and positively correlated, meaning that as the number of transactions increases, the total value of those transactions also tends to increase. All other correlations between the variables (Customer Age, Credit Limit) are very weak.

# %%
# Inactive Months, Avg Open To Buy, and Avg Utilization Ratio by Attrition Flag
numeric = ['Inactive_Months', 'Avg_Open_To_Buy', 'Avg_Utilization_Ratio']

fig, axes = plt.subplots(1, 3, figsize=(17,6))

for i, col in enumerate(numeric):
    sns.boxplot(x='Attrition_Flag', y=col, data=bank_churners, hue='Attrition_Flag', palette=['darkgreen','red'], ax=axes[i], legend=False)
    axes[i].set_title(f'{col} vs Attrition')
    axes[i].set_xlabel('Attrition_Flag')
    axes[i].set_ylabel(col)
plt.show()

# %% [markdown]
# - Inactive Months: Customers who leave tend to have a higher average number of inactive months than existing customers. This suggests inactivity could be a sign of future attrition.
# - Credit Utilization: Attrited customers have a lower average credit utilization ratio, meaning they use a smaller portion of their available credit limit. This indicates that low engagement with the credit card is linked to higher churn.
# - Open to Buy: Existing customers have a higher average "open to buy" amount (available credit) compared to those who have left. This may be because existing customers tend to have higher credit limits.

# %%
#Customer Age, Transaction Count, and Spending by Attrition Status

cols = ['Customer_Age', 'Total_Trans_Ct', 'Total_Trans_Amt']
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, col in enumerate(cols):
    sns.boxplot(
        x='Attrition_Flag',
        y=col,
        data=bank_churners,
        hue='Attrition_Flag',
        palette=['darkgreen', 'red'],
        ax=axes[i],
        legend=False
    )
    axes[i].set_title(f'{col} vs Attrition_Flag')
    axes[i].set_xlabel('')
    axes[i].set_ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
#  - The analysis showed that customers who leave the company tend to have significantly lower transaction counts and spending. Therefore, it is important to focus on engaging them with offers or monitoring low-usage customers before they churn

# %% [markdown]
#  #### Recommendations
# - The bank can focus on engaging customers with low activity (high Inactive_Months) to retain them.
# - Monitoring customers with low card utilization (low Avg_Utilization_Ratio) may help reduce attrition.
# - Analyzing the financial behavior of customers with low Total_Trans_Amt can assist in offering personalized promotions to retain them.
